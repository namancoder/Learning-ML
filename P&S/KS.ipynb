# %% [raw]
# EMPIRICAL BOOTSTRAP USING CONFIDENCE INTERVAL

# %%
import numpy
from pandas import read_csv
from sklearn.utils import resample
from sklearn.metrics import accuracy_score
from matplotlib import pyplot

# %%
#load dataset
x = numpy.array([180,162,172,168,150,171,183,165,176])#S

# %%
#configue bootstrap
n_iterations = 1000#K
n_size = int(len(x))#m

# %%
#run bootstrap
medians = list()
for i in range(n_iterations):
    #prepare train and test sets
    s = resample(x,n_samples=n_size);#takes all values of x and ask how many values you want to sample with? = n_size
    m = numpy.median(s);
    #print(m)
    medians.append(m)
#plot scores
pyplot.hist(medians)
pyplot.show()

#confidence intervals
alpha = 0.95
p=((1.0-alpha)/2.0)*100 # (1-c)/2
lower=numpy.percentile(medians, p)
p=(alpha+((1.0-alpha)/2.0))*100;
upper = numpy.percentile(medians,p)
print('%.lf confidence interval %.lf and %.lf' % (alpha*100,lower,upper))
# Out:
# 95 confidence interval 162 and 176

# %% [raw]
# K-S TEST

# %%
import numpy as np
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt

x = stats.norm.rvs(size=1000)#//generating 100 samples
sns.set_style('whitegrid')
sns.kdeplot(np.array(x), bw=0.5)
plt.show()
# Out:
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\distributions.py:1657: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)

# %%
stats.kstest(x,'norm')
#statistic = D value
# Out:
# KstestResult(statistic=0.029179513066535656, pvalue=0.3552836556012624)

# %%
#Y - continuous uniform distribution

y = np.random.uniform(0,1,10000)
sns.kdeplot(np.array(y),bw=0.1)
plt.show()
# Out:
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\distributions.py:1657: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)

# %%
stats.kstest(y,'norm')
#as p value=0 that means Y is not normally
# Out:
# KstestResult(statistic=0.5000642032187219, pvalue=0.0)
